# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in /Users/tiagomoraes/code/ufpe/redes-neurais/if702-redes-neurais/.conda/lib/python3.10/site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/tiagomoraes/code/ufpe/redes-neurais/if702-redes-neurais/.conda/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/tiagomoraes/code/ufpe/redes-neurais/if702-redes-neurais/.conda/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /Users/tiagomoraes/code/ufpe/redes-neurais/if702-redes-neurais/.conda/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /Users/tiagomoraes/code/ufpe/redes-neurais/if702-redes-neurais/.conda/lib/python3.10/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in /Users/tiagomoraes/code/ufpe/redes-neurais/if702-redes-neurais/.conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import random
import pandas as pd
from datetime import datetime, timedelta

# %%
# Atividades
ENTER_ACTIVITY = "Entrada no Estacionamento"
EXIT_ACTIVITY = "Saída do Estacionamento"
ACTIVITIES = ["Solicitar Ticket", "Scan Sem Parar", "Impressão do Ticket", "Scan Sem Parar", "Pagar Estacionamento", "Validar Ticket", "Perda de Ticket", "Reservar Vaga", "Cancelar Reserva", "Comprar Cartão Pré-pago", "Adicionar Créditos", "Cancelar Cartão Pré-pago", "Leitura do Cartão Pré-pago"]

# Regras de precedência
PRECEDENCE = {
    "Solicitar Ticket": [ENTER_ACTIVITY],
    "Scan Sem Parar": [ENTER_ACTIVITY],
    "Impressão do Ticket": ["Solicitar Ticket"],
    "Validar Ticket": ["Impressão do Ticket"],
    "Pagar Estacionamento": ["Validar Ticket"],
    "Cancelar Reserva": ["Reservar Vaga"],
    "Perda de Ticket": ["Impressão do Ticket"],
    "Cancelar Cartão Pré-pago": ["Comprar Cartão Pré-pago"],
    EXIT_ACTIVITY: ["Scan Sem Parar", "Validar Ticket", "Leitura do Cartão Pré-pago"],
}

# Regras de obrigação
OBLIGATION = {
    "Reservar Vaga": ["Cancelar Reserva", "Entrada no Estacionamento"],
    "Soliciar Ticket": ["Impressão do Ticket"],
}

# Regras de proibição
PROHIBITION = {
    "Adicionar Crédito": ["Cancelar Cartão Pré-pago"],
}

# Probabilidades das atividades (pesos)
ACTIVITY_PROBABILITY = {
    ENTER_ACTIVITY: 0,
    "Solicitar Ticket": 10,
    "Impressão do Ticket": 9.5,
    "Scan Sem Parar": 1,
    "Pagar Estacionamento": 8,
    "Validar Ticket": 8,
    "Perda de Ticket": 0.2,
    "Reservar Vaga": 1,
    "Cancelar Reserva": 0.4,
    "Comprar Cartão Pré-pago": 1.5,
    "Adicionar Créditos": 2,
    "Cancelar Cartão Pré-pago": 0.3,
    "Leitura do Cartão Pré-pago": 3,
    EXIT_ACTIVITY: 10,
}

ACTIVITY_DURATIONS = {
    ENTER_ACTIVITY: 0,
    "Solicitar Ticket": 10,
    "Impressão do Ticket": 10,
    "Scan Sem Parar": 2,
    "Pagar Estacionamento": 80,
    "Validar Ticket": 6,
    "Perda de Ticket": 0,
    "Reservar Vaga": 120,
    "Cancelar Reserva": 40,
    "Comprar Cartão Pré-pago": 180,
    "Adicionar Créditos": 40,
    "Cancelar Cartão Pré-pago": 480,
    "Leitura do Cartão Pré-pago": 2,
    EXIT_ACTIVITY: 0,
}

# Recursos disponíveis
RESOURCES = ["PCR8249", "RZQ8I54", "PCK0O98", "PAB8H80", "KHH6204", "SCR1905", "KHH6984", "KHI0043", "PCC1I09", "KIE0IOP", "JAC1990", "DOP0POP", "ASD4578", "ALK1L34", "KPA3B84", "PLL8G47", "PEC2468", "KHH4405", "KEA2308", "KED4O69"]

# Gera a próxima atividade aleatoriamente com base nas probabilidades
def get_next_activity(current_activity, case_activities, demanded_activities):
    all_possible_activities = ACTIVITIES + [EXIT_ACTIVITY]
    possible_next_activities = set()

    # Verifica as atividades que podem ser executadas em seguida, respeitando a precedência
    for activity in all_possible_activities:
        if activity == ENTER_ACTIVITY:
            continue
        if activity == current_activity:
            continue
        if activity in PRECEDENCE and any(dep in case_activities for dep in PRECEDENCE[activity]):
            possible_next_activities.add(activity)
        elif activity not in PRECEDENCE:
            possible_next_activities.add(activity)
        else:
            pass
    
    # Remove proíbições, caso haja alguma para o caso atual
    for done_activity in case_activities:
        if done_activity in PROHIBITION and any(dep in possible_next_activities for dep in PROHIBITION[done_activity]):
            possible_next_activities.remove(done_activity)

    # Seleciona aleatoriamente a próxima atividade com base nas probabilidades
    possible_next_activities = list(possible_next_activities)
    most_possible_next_activities = random.choices(possible_next_activities, weights=[ACTIVITY_PROBABILITY[activity] for activity in possible_next_activities])
    next_activity = most_possible_next_activities[0]

    if next_activity == EXIT_ACTIVITY and len(demanded_activities) > 0:
        current_demanded_activities = list(demanded_activities)
        next_activity = random.choices(current_demanded_activities, weights=[ACTIVITY_PROBABILITY[activity] for activity in current_demanded_activities])[0]
        demanded_activities.remove(next_activity)

    # Verifica as atividades obrigatórias
    if next_activity in OBLIGATION:
        obligations = OBLIGATION[next_activity]
        obl = random.choices(obligations, weights=[ACTIVITY_PROBABILITY[activity] for activity in obligations])[0]
        if obl not in case_activities:
            demanded_activities.add(obl)

    return next_activity

# Gera uma sequência de atividades para um caso, respeitando as regras de precedência e obrigações
def generate_activities():
    case_activities = [ENTER_ACTIVITY]
    demanded_activities = set()

    while True:
        current_activity = case_activities[-1]
        next_activity = get_next_activity(current_activity, case_activities, demanded_activities)
        case_activities.append(next_activity)
        if next_activity == EXIT_ACTIVITY:
            demanded_activities.clear()
            break

    return case_activities

# Gera o log sintético de atividades
def generate_log(num_cases):
    log_data = []
    resource = random.choice(RESOURCES)
    for i in range(num_cases):
        print(f'Gerando caso {i}')
        case_activities = generate_activities()
        start_time = datetime(2023, 7, 1, random.randint(7, 12), random.randint(0, 59), 0)
        for activity in case_activities:
            if activity == ENTER_ACTIVITY:
                resource = random.choice(RESOURCES)  # Escolhe um novo recurso para as atividades de entrada
            expected_duration = ACTIVITY_DURATIONS[activity]
            duration = random.randint(round(0.6 * expected_duration), round(2 * expected_duration))  # Duração aleatória em minutos
            end_time = start_time + timedelta(seconds=duration)
            log_data.append([i + 1, activity, resource, start_time.strftime("%Y-%m-%d %H:%M:%S"), end_time.strftime("%Y-%m-%d %H:%M:%S")])

            # Se atividades levarem a ficar no estabelecimento, demora um pouco mais para a próxima atividade
            if (activity == "Impressão do Ticket" or activity == "Scan Sem Parar"):
                start_time = end_time + timedelta(minutes=random.randint(0, 240))
            else:
                start_time = end_time + timedelta(seconds=random.randint(0, 60))
    return log_data

# Função para escrever o log em um arquivo CSV
def write_log_to_csv(df, filename):
    df.to_csv(filename, index=False)

# %%
if __name__ == "__main__":
    num_cases = 1000
    log_data = generate_log(num_cases)
    df = pd.DataFrame(log_data, columns=["Caso", "Atividade", "Recurso", "Início", "Fim"])
    print(df)

    # Escreve o log em um arquivo CSV chamado "log_estacionamento.csv"
    write_log_to_csv(df, "log_estacionamento.csv")
# Out:
# Gerando caso 0
# Gerando caso 1
# Gerando caso 2
# Gerando caso 3
# Gerando caso 4
# Gerando caso 5
# Gerando caso 6
# Gerando caso 7
# Gerando caso 8
# Gerando caso 9
# Gerando caso 10
# Gerando caso 11
# Gerando caso 12
# Gerando caso 13
# Gerando caso 14
# Gerando caso 15
# Gerando caso 16
# Gerando caso 17
# Gerando caso 18
# Gerando caso 19
# Gerando caso 20
# Gerando caso 21
# Gerando caso 22
# Gerando caso 23
# Gerando caso 24
# Gerando caso 25
# Gerando caso 26
# Gerando caso 27
# Gerando caso 28
# Gerando caso 29
# Gerando caso 30
# Gerando caso 31
# Gerando caso 32
# Gerando caso 33
# Gerando caso 34
# Gerando caso 35
# Gerando caso 36
# Gerando caso 37
# Gerando caso 38
# Gerando caso 39
# Gerando caso 40
# Gerando caso 41
# Gerando caso 42
# Gerando caso 43
# Gerando caso 44
# Gerando caso 45
# Gerando caso 46
# Gerando caso 47
# Gerando caso 48
# Gerando caso 49
# Gerando caso 50
# Gerando caso 51
# Gerando caso 52
# Gerando caso 53
# Gerando caso 54
# Gerando caso 55
# Gerando caso 56
# Gerando caso 57
# Gerando caso 58
# Gerando caso 59
# Gerando caso 60
# Gerando caso 61
# Gerando caso 62
# Gerando caso 63
# Gerando caso 64
# Gerando caso 65
# Gerando caso 66
# Gerando caso 67
# Gerando caso 68
# Gerando caso 69
# Gerando caso 70
# Gerando caso 71
# Gerando caso 72
# Gerando caso 73
# Gerando caso 74
# Gerando caso 75
# Gerando caso 76
# Gerando caso 77
# Gerando caso 78
# Gerando caso 79
# Gerando caso 80
# Gerando caso 81
# Gerando caso 82
# Gerando caso 83
# Gerando caso 84
# Gerando caso 85
# Gerando caso 86
# Gerando caso 87
# Gerando caso 88
# Gerando caso 89
# Gerando caso 90
# Gerando caso 91
# Gerando caso 92
# Gerando caso 93
# Gerando caso 94
# Gerando caso 95
# Gerando caso 96
# Gerando caso 97
# Gerando caso 98
# Gerando caso 99
# Gerando caso 100
# Gerando caso 101
# Gerando caso 102
# Gerando caso 103
# Gerando caso 104
# Gerando caso 105
# Gerando caso 106
# Gerando caso 107
# Gerando caso 108
# Gerando caso 109
# Gerando caso 110
# Gerando caso 111
# Gerando caso 112
# Gerando caso 113
# Gerando caso 114
# Gerando caso 115
# Gerando caso 116
# Gerando caso 117
# Gerando caso 118
# Gerando caso 119
# Gerando caso 120
# Gerando caso 121
# Gerando caso 122
# Gerando caso 123
# Gerando caso 124
# Gerando caso 125
# Gerando caso 126
# Gerando caso 127
# Gerando caso 128
# Gerando caso 129
# Gerando caso 130
# Gerando caso 131
# Gerando caso 132
# Gerando caso 133
# Gerando caso 134
# Gerando caso 135
# Gerando caso 136
# Gerando caso 137
# Gerando caso 138
# Gerando caso 139
# Gerando caso 140
# Gerando caso 141
# Gerando caso 142
# Gerando caso 143
# Gerando caso 144
# Gerando caso 145
# Gerando caso 146
# Gerando caso 147
# Gerando caso 148
# Gerando caso 149
# Gerando caso 150
# Gerando caso 151
# Gerando caso 152
# Gerando caso 153
# Gerando caso 154
# Gerando caso 155
# Gerando caso 156
# Gerando caso 157
# Gerando caso 158
# Gerando caso 159
# Gerando caso 160
# Gerando caso 161
# Gerando caso 162
# Gerando caso 163
# Gerando caso 164
# Gerando caso 165
# Gerando caso 166
# Gerando caso 167
# Gerando caso 168
# Gerando caso 169
# Gerando caso 170
# Gerando caso 171
# Gerando caso 172
# Gerando caso 173
# Gerando caso 174
# Gerando caso 175
# Gerando caso 176
# Gerando caso 177
# Gerando caso 178
# Gerando caso 179
# Gerando caso 180
# Gerando caso 181
# Gerando caso 182
# Gerando caso 183
# Gerando caso 184
# Gerando caso 185
# Gerando caso 186
# Gerando caso 187
# Gerando caso 188
# Gerando caso 189
# Gerando caso 190
# Gerando caso 191
# Gerando caso 192
# Gerando caso 193
# Gerando caso 194
# Gerando caso 195
# Gerando caso 196
# Gerando caso 197
# Gerando caso 198
# Gerando caso 199
# Gerando caso 200
# Gerando caso 201
# Gerando caso 202
# Gerando caso 203
# Gerando caso 204
# Gerando caso 205
# Gerando caso 206
# Gerando caso 207
# Gerando caso 208
# Gerando caso 209
# Gerando caso 210
# Gerando caso 211
# Gerando caso 212
# Gerando caso 213
# Gerando caso 214
# Gerando caso 215
# Gerando caso 216
# Gerando caso 217
# Gerando caso 218
# Gerando caso 219
# Gerando caso 220
# Gerando caso 221
# Gerando caso 222
# Gerando caso 223
# Gerando caso 224
# Gerando caso 225
# Gerando caso 226
# Gerando caso 227
# Gerando caso 228
# Gerando caso 229
# Gerando caso 230
# Gerando caso 231
# Gerando caso 232
# Gerando caso 233
# Gerando caso 234
# Gerando caso 235
# Gerando caso 236
# Gerando caso 237
# Gerando caso 238
# Gerando caso 239
# Gerando caso 240
# Gerando caso 241
# Gerando caso 242
# Gerando caso 243
# Gerando caso 244
# Gerando caso 245
# Gerando caso 246
# Gerando caso 247
# Gerando caso 248
# Gerando caso 249
# Gerando caso 250
# Gerando caso 251
# Gerando caso 252
# Gerando caso 253
# Gerando caso 254
# Gerando caso 255
# Gerando caso 256
# Gerando caso 257
# Gerando caso 258
# Gerando caso 259
# Gerando caso 260
# Gerando caso 261
# Gerando caso 262
# Gerando caso 263
# Gerando caso 264
# Gerando caso 265
# Gerando caso 266
# Gerando caso 267
# Gerando caso 268
# Gerando caso 269
# Gerando caso 270
# Gerando caso 271
# Gerando caso 272
# Gerando caso 273
# Gerando caso 274
# Gerando caso 275
# Gerando caso 276
# Gerando caso 277
# Gerando caso 278
# Gerando caso 279
# Gerando caso 280
# Gerando caso 281
# Gerando caso 282
# Gerando caso 283
# Gerando caso 284
# Gerando caso 285
# Gerando caso 286
# Gerando caso 287
# Gerando caso 288
# Gerando caso 289
# Gerando caso 290
# Gerando caso 291
# Gerando caso 292
# Gerando caso 293
# Gerando caso 294
# Gerando caso 295
# Gerando caso 296
# Gerando caso 297
# Gerando caso 298
# Gerando caso 299
# Gerando caso 300
# Gerando caso 301
# Gerando caso 302
# Gerando caso 303
# Gerando caso 304
# Gerando caso 305
# Gerando caso 306
# Gerando caso 307
# Gerando caso 308
# Gerando caso 309
# Gerando caso 310
# Gerando caso 311
# Gerando caso 312
# Gerando caso 313
# Gerando caso 314
# Gerando caso 315
# Gerando caso 316
# Gerando caso 317
# Gerando caso 318
# Gerando caso 319
# Gerando caso 320
# Gerando caso 321
# Gerando caso 322
# Gerando caso 323
# Gerando caso 324
# Gerando caso 325
# Gerando caso 326
# Gerando caso 327
# Gerando caso 328
# Gerando caso 329
# Gerando caso 330
# Gerando caso 331
# Gerando caso 332
# Gerando caso 333
# Gerando caso 334
# Gerando caso 335
# Gerando caso 336
# Gerando caso 337
# Gerando caso 338
# Gerando caso 339
# Gerando caso 340
# Gerando caso 341
# Gerando caso 342
# Gerando caso 343
# Gerando caso 344
# Gerando caso 345
# Gerando caso 346
# Gerando caso 347
# Gerando caso 348
# Gerando caso 349
# Gerando caso 350
# Gerando caso 351
# Gerando caso 352
# Gerando caso 353
# Gerando caso 354
# Gerando caso 355
# Gerando caso 356
# Gerando caso 357
# Gerando caso 358
# Gerando caso 359
# Gerando caso 360
# Gerando caso 361
# Gerando caso 362
# Gerando caso 363
# Gerando caso 364
# Gerando caso 365
# Gerando caso 366
# Gerando caso 367
# Gerando caso 368
# Gerando caso 369
# Gerando caso 370
# Gerando caso 371
# Gerando caso 372
# Gerando caso 373
# Gerando caso 374
# Gerando caso 375
# Gerando caso 376
# Gerando caso 377
# Gerando caso 378
# Gerando caso 379
# Gerando caso 380
# Gerando caso 381
# Gerando caso 382
# Gerando caso 383
# Gerando caso 384
# Gerando caso 385
# Gerando caso 386
# Gerando caso 387
# Gerando caso 388
# Gerando caso 389
# Gerando caso 390
# Gerando caso 391
# Gerando caso 392
# Gerando caso 393
# Gerando caso 394
# Gerando caso 395
# Gerando caso 396
# Gerando caso 397
# Gerando caso 398
# Gerando caso 399
# Gerando caso 400
# Gerando caso 401
# Gerando caso 402
# Gerando caso 403
# Gerando caso 404
# Gerando caso 405
# Gerando caso 406
# Gerando caso 407
# Gerando caso 408
# Gerando caso 409
# Gerando caso 410
# Gerando caso 411
# Gerando caso 412
# Gerando caso 413
# Gerando caso 414
# Gerando caso 415
# Gerando caso 416
# Gerando caso 417
# Gerando caso 418
# Gerando caso 419
# Gerando caso 420
# Gerando caso 421
# Gerando caso 422
# Gerando caso 423
# Gerando caso 424
# Gerando caso 425
# Gerando caso 426
# Gerando caso 427
# Gerando caso 428
# Gerando caso 429
# Gerando caso 430
# Gerando caso 431
# Gerando caso 432
# Gerando caso 433
# Gerando caso 434
# Gerando caso 435
# Gerando caso 436
# Gerando caso 437
# Gerando caso 438
# Gerando caso 439
# Gerando caso 440
# Gerando caso 441
# Gerando caso 442
# Gerando caso 443
# Gerando caso 444
# Gerando caso 445
# Gerando caso 446
# Gerando caso 447
# Gerando caso 448
# Gerando caso 449
# Gerando caso 450
# Gerando caso 451
# Gerando caso 452
# Gerando caso 453
# Gerando caso 454
# Gerando caso 455
# Gerando caso 456
# Gerando caso 457
# Gerando caso 458
# Gerando caso 459
# Gerando caso 460
# Gerando caso 461
# Gerando caso 462
# Gerando caso 463
# Gerando caso 464
# Gerando caso 465
# Gerando caso 466
# Gerando caso 467
# Gerando caso 468
# Gerando caso 469
# Gerando caso 470
# Gerando caso 471
# Gerando caso 472
# Gerando caso 473
# Gerando caso 474
# Gerando caso 475
# Gerando caso 476
# Gerando caso 477
# Gerando caso 478
# Gerando caso 479
# Gerando caso 480
# Gerando caso 481
# Gerando caso 482
# Gerando caso 483
# Gerando caso 484
# Gerando caso 485
# Gerando caso 486
# Gerando caso 487
# Gerando caso 488
# Gerando caso 489
# Gerando caso 490
# Gerando caso 491
# Gerando caso 492
# Gerando caso 493
# Gerando caso 494
# Gerando caso 495
# Gerando caso 496
# Gerando caso 497
# Gerando caso 498
# Gerando caso 499
# Gerando caso 500
# Gerando caso 501
# Gerando caso 502
# Gerando caso 503
# Gerando caso 504
# Gerando caso 505
# Gerando caso 506
# Gerando caso 507
# Gerando caso 508
# Gerando caso 509
# Gerando caso 510
# Gerando caso 511
# Gerando caso 512
# Gerando caso 513
# Gerando caso 514
# Gerando caso 515
# Gerando caso 516
# Gerando caso 517
# Gerando caso 518
# Gerando caso 519
# Gerando caso 520
# Gerando caso 521
# Gerando caso 522
# Gerando caso 523
# Gerando caso 524
# Gerando caso 525
# Gerando caso 526
# Gerando caso 527
# Gerando caso 528
# Gerando caso 529
# Gerando caso 530
# Gerando caso 531
# Gerando caso 532
# Gerando caso 533
# Gerando caso 534
# Gerando caso 535
# Gerando caso 536
# Gerando caso 537
# Gerando caso 538
# Gerando caso 539
# Gerando caso 540
# Gerando caso 541
# Gerando caso 542
# Gerando caso 543
# Gerando caso 544
# Gerando caso 545
# Gerando caso 546
# Gerando caso 547
# Gerando caso 548
# Gerando caso 549
# Gerando caso 550
# Gerando caso 551
# Gerando caso 552
# Gerando caso 553
# Gerando caso 554
# Gerando caso 555
# Gerando caso 556
# Gerando caso 557
# Gerando caso 558
# Gerando caso 559
# Gerando caso 560
# Gerando caso 561
# Gerando caso 562
# Gerando caso 563
# Gerando caso 564
# Gerando caso 565
# Gerando caso 566
# Gerando caso 567
# Gerando caso 568
# Gerando caso 569
# Gerando caso 570
# Gerando caso 571
# Gerando caso 572
# Gerando caso 573
# Gerando caso 574
# Gerando caso 575
# Gerando caso 576
# Gerando caso 577
# Gerando caso 578
# Gerando caso 579
# Gerando caso 580
# Gerando caso 581
# Gerando caso 582
# Gerando caso 583
# Gerando caso 584
# Gerando caso 585
# Gerando caso 586
# Gerando caso 587
# Gerando caso 588
# Gerando caso 589
# Gerando caso 590
# Gerando caso 591
# Gerando caso 592
# Gerando caso 593
# Gerando caso 594
# Gerando caso 595
# Gerando caso 596
# Gerando caso 597
# Gerando caso 598
# Gerando caso 599
# Gerando caso 600
# Gerando caso 601
# Gerando caso 602
# Gerando caso 603
# Gerando caso 604
# Gerando caso 605
# Gerando caso 606
# Gerando caso 607
# Gerando caso 608
# Gerando caso 609
# Gerando caso 610
# Gerando caso 611
# Gerando caso 612
# Gerando caso 613
# Gerando caso 614
# Gerando caso 615
# Gerando caso 616
# Gerando caso 617
# Gerando caso 618
# Gerando caso 619
# Gerando caso 620
# Gerando caso 621
# Gerando caso 622
# Gerando caso 623
# Gerando caso 624
# Gerando caso 625
# Gerando caso 626
# Gerando caso 627
# Gerando caso 628
# Gerando caso 629
# Gerando caso 630
# Gerando caso 631
# Gerando caso 632
# Gerando caso 633
# Gerando caso 634
# Gerando caso 635
# Gerando caso 636
# Gerando caso 637
# Gerando caso 638
# Gerando caso 639
# Gerando caso 640
# Gerando caso 641
# Gerando caso 642
# Gerando caso 643
# Gerando caso 644
# Gerando caso 645
# Gerando caso 646
# Gerando caso 647
# Gerando caso 648
# Gerando caso 649
# Gerando caso 650
# Gerando caso 651
# Gerando caso 652
# Gerando caso 653
# Gerando caso 654
# Gerando caso 655
# Gerando caso 656
# Gerando caso 657
# Gerando caso 658
# Gerando caso 659
# Gerando caso 660
# Gerando caso 661
# Gerando caso 662
# Gerando caso 663
# Gerando caso 664
# Gerando caso 665
# Gerando caso 666
# Gerando caso 667
# Gerando caso 668
# Gerando caso 669
# Gerando caso 670
# Gerando caso 671
# Gerando caso 672
# Gerando caso 673
# Gerando caso 674
# Gerando caso 675
# Gerando caso 676
# Gerando caso 677
# Gerando caso 678
# Gerando caso 679
# Gerando caso 680
# Gerando caso 681
# Gerando caso 682
# Gerando caso 683
# Gerando caso 684
# Gerando caso 685
# Gerando caso 686
# Gerando caso 687
# Gerando caso 688
# Gerando caso 689
# Gerando caso 690
# Gerando caso 691
# Gerando caso 692
# Gerando caso 693
# Gerando caso 694
# Gerando caso 695
# Gerando caso 696
# Gerando caso 697
# Gerando caso 698
# Gerando caso 699
# Gerando caso 700
# Gerando caso 701
# Gerando caso 702
# Gerando caso 703
# Gerando caso 704
# Gerando caso 705
# Gerando caso 706
# Gerando caso 707
# Gerando caso 708
# Gerando caso 709
# Gerando caso 710
# Gerando caso 711
# Gerando caso 712
# Gerando caso 713
# Gerando caso 714
# Gerando caso 715
# Gerando caso 716
# Gerando caso 717
# Gerando caso 718
# Gerando caso 719
# Gerando caso 720
# Gerando caso 721
# Gerando caso 722
# Gerando caso 723
# Gerando caso 724
# Gerando caso 725
# Gerando caso 726
# Gerando caso 727
# Gerando caso 728
# Gerando caso 729
# Gerando caso 730
# Gerando caso 731
# Gerando caso 732
# Gerando caso 733
# Gerando caso 734
# Gerando caso 735
# Gerando caso 736
# Gerando caso 737
# Gerando caso 738
# Gerando caso 739
# Gerando caso 740
# Gerando caso 741
# Gerando caso 742
# Gerando caso 743
# Gerando caso 744
# Gerando caso 745
# Gerando caso 746
# Gerando caso 747
# Gerando caso 748
# Gerando caso 749
# Gerando caso 750
# Gerando caso 751
# Gerando caso 752
# Gerando caso 753
# Gerando caso 754
# Gerando caso 755
# Gerando caso 756
# Gerando caso 757
# Gerando caso 758
# Gerando caso 759
# Gerando caso 760
# Gerando caso 761
# Gerando caso 762
# Gerando caso 763
# Gerando caso 764
# Gerando caso 765
# Gerando caso 766
# Gerando caso 767
# Gerando caso 768
# Gerando caso 769
# Gerando caso 770
# Gerando caso 771
# Gerando caso 772
# Gerando caso 773
# Gerando caso 774
# Gerando caso 775
# Gerando caso 776
# Gerando caso 777
# Gerando caso 778
# Gerando caso 779
# Gerando caso 780
# Gerando caso 781
# Gerando caso 782
# Gerando caso 783
# Gerando caso 784
# Gerando caso 785
# Gerando caso 786
# Gerando caso 787
# Gerando caso 788
# Gerando caso 789
# Gerando caso 790
# Gerando caso 791
# Gerando caso 792
# Gerando caso 793
# Gerando caso 794
# Gerando caso 795
# Gerando caso 796
# Gerando caso 797
# Gerando caso 798
# Gerando caso 799
# Gerando caso 800
# Gerando caso 801
# Gerando caso 802
# Gerando caso 803
# Gerando caso 804
# Gerando caso 805
# Gerando caso 806
# Gerando caso 807
# Gerando caso 808
# Gerando caso 809
# Gerando caso 810
# Gerando caso 811
# Gerando caso 812
# Gerando caso 813
# Gerando caso 814
# Gerando caso 815
# Gerando caso 816
# Gerando caso 817
# Gerando caso 818
# Gerando caso 819
# Gerando caso 820
# Gerando caso 821
# Gerando caso 822
# Gerando caso 823
# Gerando caso 824
# Gerando caso 825
# Gerando caso 826
# Gerando caso 827
# Gerando caso 828
# Gerando caso 829
# Gerando caso 830
# Gerando caso 831
# Gerando caso 832
# Gerando caso 833
# Gerando caso 834
# Gerando caso 835
# Gerando caso 836
# Gerando caso 837
# Gerando caso 838
# Gerando caso 839
# Gerando caso 840
# Gerando caso 841
# Gerando caso 842
# Gerando caso 843
# Gerando caso 844
# Gerando caso 845
# Gerando caso 846
# Gerando caso 847
# Gerando caso 848
# Gerando caso 849
# Gerando caso 850
# Gerando caso 851
# Gerando caso 852
# Gerando caso 853
# Gerando caso 854
# Gerando caso 855
# Gerando caso 856
# Gerando caso 857
# Gerando caso 858
# Gerando caso 859
# Gerando caso 860
# Gerando caso 861
# Gerando caso 862
# Gerando caso 863
# Gerando caso 864
# Gerando caso 865
# Gerando caso 866
# Gerando caso 867
# Gerando caso 868
# Gerando caso 869
# Gerando caso 870
# Gerando caso 871
# Gerando caso 872
# Gerando caso 873
# Gerando caso 874
# Gerando caso 875
# Gerando caso 876
# Gerando caso 877
# Gerando caso 878
# Gerando caso 879
# Gerando caso 880
# Gerando caso 881
# Gerando caso 882
# Gerando caso 883
# Gerando caso 884
# Gerando caso 885
# Gerando caso 886
# Gerando caso 887
# Gerando caso 888
# Gerando caso 889
# Gerando caso 890
# Gerando caso 891
# Gerando caso 892
# Gerando caso 893
# Gerando caso 894
# Gerando caso 895
# Gerando caso 896
# Gerando caso 897
# Gerando caso 898
# Gerando caso 899
# Gerando caso 900
# Gerando caso 901
# Gerando caso 902
# Gerando caso 903
# Gerando caso 904
# Gerando caso 905
# Gerando caso 906
# Gerando caso 907
# Gerando caso 908
# Gerando caso 909
# Gerando caso 910
# Gerando caso 911
# Gerando caso 912
# Gerando caso 913
# Gerando caso 914
# Gerando caso 915
# Gerando caso 916
# Gerando caso 917
# Gerando caso 918
# Gerando caso 919
# Gerando caso 920
# Gerando caso 921
# Gerando caso 922
# Gerando caso 923
# Gerando caso 924
# Gerando caso 925
# Gerando caso 926
# Gerando caso 927
# Gerando caso 928
# Gerando caso 929
# Gerando caso 930
# Gerando caso 931
# Gerando caso 932
# Gerando caso 933
# Gerando caso 934
# Gerando caso 935
# Gerando caso 936
# Gerando caso 937
# Gerando caso 938
# Gerando caso 939
# Gerando caso 940
# Gerando caso 941
# Gerando caso 942
# Gerando caso 943
# Gerando caso 944
# Gerando caso 945
# Gerando caso 946
# Gerando caso 947
# Gerando caso 948
# Gerando caso 949
# Gerando caso 950
# Gerando caso 951
# Gerando caso 952
# Gerando caso 953
# Gerando caso 954
# Gerando caso 955
# Gerando caso 956
# Gerando caso 957
# Gerando caso 958
# Gerando caso 959
# Gerando caso 960
# Gerando caso 961
# Gerando caso 962
# Gerando caso 963
# Gerando caso 964
# Gerando caso 965
# Gerando caso 966
# Gerando caso 967
# Gerando caso 968
# Gerando caso 969
# Gerando caso 970
# Gerando caso 971
# Gerando caso 972
# Gerando caso 973
# Gerando caso 974
# Gerando caso 975
# Gerando caso 976
# Gerando caso 977
# Gerando caso 978
# Gerando caso 979
# Gerando caso 980
# Gerando caso 981
# Gerando caso 982
# Gerando caso 983
# Gerando caso 984
# Gerando caso 985
# Gerando caso 986
# Gerando caso 987
# Gerando caso 988
# Gerando caso 989
# Gerando caso 990
# Gerando caso 991
# Gerando caso 992
# Gerando caso 993
# Gerando caso 994
# Gerando caso 995
# Gerando caso 996
# Gerando caso 997
# Gerando caso 998
# Gerando caso 999
#       Caso                   Atividade  Recurso               Início  \
# 0        1   Entrada no Estacionamento  PCC1I09  2023-07-01 08:46:00
# 1        1              Scan Sem Parar  PCC1I09  2023-07-01 08:46:20
# 2        1  Leitura do Cartão Pré-pago  PCC1I09  2023-07-01 10:38:23
# 3        1     Saída do Estacionamento  PCC1I09  2023-07-01 10:39:14
# 4        2   Entrada no Estacionamento  RZQ8I54  2023-07-01 08:24:00
# ...    ...                         ...      ...                  ...
# 9485  1000            Solicitar Ticket  JAC1990  2023-07-01 16:42:02
# 9486  1000        Pagar Estacionamento  JAC1990  2023-07-01 16:43:07
# 9487  1000  Leitura do Cartão Pré-pago  JAC1990  2023-07-01 16:45:43
# 9488  1000            Solicitar Ticket  JAC1990  2023-07-01 16:46:43
# 9489  1000     Saída do Estacionamento  JAC1990  2023-07-01 16:47:18
#
#                       Fim
# 0     2023-07-01 08:46:00
# 1     2023-07-01 08:46:23
# 2     2023-07-01 10:38:25
# 3     2023-07-01 10:39:14
# 4     2023-07-01 08:24:00
# ...                   ...
# 9485  2023-07-01 16:42:13
# 9486  2023-07-01 16:44:57
# 9487  2023-07-01 16:45:47
# 9488  2023-07-01 16:46:57
# 9489  2023-07-01 16:47:18
#
# [9490 rows x 5 columns]
